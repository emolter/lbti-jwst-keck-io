# %% [markdown]
# # Volcano finder with photutils
#
# Tests out the functionality of photutils.psf and photutils.detection to find sources in LBTI images

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import paths
from photutils.psf import (BasicPSFPhotometry, IterativelySubtractedPSFPhotometry, DAOGroup)
from photutils.detection import StarFinder
from photutils.background import BiweightLocationBackground
from astropy.io import fits
from astropy.table import Table, vstack

# %%
# load the PSF from make-psf.ipynb
with open(paths.data / 'psf_fittable_model.pkl', 'rb') as f:
    epsf = pickle.load(f)
print(type(epsf))

# load the data cube
io_fits = fits.open(paths.data / 'lucky_nav.fits')
io_data = io_cube[0].data
# Out:
# <class 'photutils.psf.models.EPSFModel'>
# Name: EPSFModel (FittableImageModel)
# N_inputs: 2
# N_outputs: 1
# Fittable parameters: ('flux', 'x_0', 'y_0')

# %%
# instantiate a star finder and group maker
separation_dist = 20
thresh = np.mean(io_data) #+ 3*np.std(io_data)
star_finder = StarFinder(thresh, epsf.data) #threshold, kernel
group_maker = DAOGroup(separation_dist)
bkgd_estimator = BiweightLocationBackground()

# use these to do PSF fitting
source_extractor = IterativelySubtractedPSFPhotometry(group_maker, bkgd_estimator, epsf, epsf.data.shape, star_finder)

resids = []
result_tab = []
for i in range(io_data.shape[0]):
    ith_tab = source_extractor(image=io_data[i, 40:120, 40:120]) #excise center of planet; 
    print(ith_tab)
    result_tab.append(ith_tab)
    residual_image = source_extractor.get_residual_image()
    resids.append(residual_image)
emakong_tab = vstack([j[0] for j in result_tab])
print(emakong_tab)
# Out:
# WARNING: aperture_radius is None and could not be determined by psf_model. Setting radius to the smallest fitshape size. This aperture radius will be used if initial fluxes require computing for any input stars. If fitshape is significantly larger than the psf_model core lengthscale, consider supplying a specific aperture_radius. [photutils.psf.photometry]
#        x_0              x_fit        ...       y_0_unc       iter_detected
# ----------------- ------------------ ... ------------------- -------------
# 46.47810155948061 46.769154915394516 ... 0.09759445310888121             1
#        x_0              x_fit        ...      y_0_unc       iter_detected
# ----------------- ------------------ ... ------------------ -------------
# 47.59924343444381 47.827464151229506 ... 0.0964723324893014             1
#        x_0              x_fit       ...      y_0_unc       iter_detected
# ----------------- ----------------- ... ------------------ -------------
# 45.80819589010773 45.85259838932409 ... 0.0909553779176946             1
#        x_0               x_fit       ...       y_0_unc       iter_detected
# ------------------ ----------------- ... ------------------- -------------
# 45.697678056825765 45.68061452335745 ... 0.09684245887863646             1
#        x_0              x_fit        ...       y_0_unc       iter_detected
# ----------------- ------------------ ... ------------------- -------------
# 46.47650109860289 47.097568283620475 ... 0.08157746035117652             1
#       x_0              x_fit       ...       y_0_unc       iter_detected
# ---------------- ----------------- ... ------------------- -------------
# 46.7552697024983 47.24887161705092 ... 0.09330180618808992             1
#        x_0              x_fit       ...       y_0_unc       iter_detected
# ----------------- ----------------- ... ------------------- -------------
# 46.53443742136066 47.10419305831734 ... 0.10302054658049421             1
#        x_0              x_fit       ...       y_0_unc       iter_detected
# ----------------- ----------------- ... ------------------- -------------
# 46.71529508051792 47.42422742448208 ... 0.09212822673060736             1
#        x_0               x_fit       ...       y_0_unc       iter_detected
# ------------------ ----------------- ... ------------------- -------------
# 47.397688329509236 47.65908694944344 ... 0.10123990423736565             1
#        x_0              x_fit       ...       y_0_unc       iter_detected
# ------------------ ---------------- ... ------------------- -------------
# 46.421929233131635 46.0658921366005 ... 0.09426634199385342             1
#        x_0              x_fit       ...       y_0_unc       iter_detected
# ----------------- ----------------- ... ------------------- -------------
# 45.59741120558199 45.29002801497145 ... 0.12126561801473437             1
#        x_0               x_fit       ...     y_0_unc      iter_detected
# ------------------ ----------------- ... ---------------- -------------
# 45.614981428351996 45.24960703220134 ... 0.08748856965982             1
#       x_0              x_fit       ...       y_0_unc       iter_detected
# ---------------- ----------------- ... ------------------- -------------
# 46.5064398096136 45.92873667374882 ... 0.08176619873878889             1
#        x_0              x_fit        ...       y_0_unc       iter_detected
# ----------------- ------------------ ... ------------------- -------------
# 46.19701678713753 46.310514314197455 ... 0.08364795216048308             1
#        x_0             x_fit       ...       y_0_unc       iter_detected
# ----------------- ---------------- ... ------------------- -------------
# 46.86851900879688 47.5158853118792 ... 0.10965496056302766             1
#        x_0              x_fit       ...       y_0_unc       iter_detected
# ----------------- ----------------- ... ------------------- -------------
# 46.46269622986529 46.12066826174794 ... 0.08330694576008527             1
#        x_0              x_fit       ...       y_0_unc       iter_detected
# ----------------- ----------------- ... ------------------- -------------
# 46.57884680437056 46.70161678340357 ... 0.10341848792003375             1
#        x_0              x_fit        ...       y_0_unc       iter_detected
# ----------------- ------------------ ... ------------------- -------------
# 46.74461660540184 46.175220519334516 ... 0.09753969791964806             1
#        x_0               x_fit        ...       y_0_unc       iter_detected
# ------------------ ------------------ ... ------------------- -------------
# 47.533106469027544 48.186763650726405 ... 0.09455070228316054             1
#        x_0              x_fit       ...       y_0_unc       iter_detected
# ----------------- ----------------- ... ------------------- -------------
# 46.23331150267879 46.33621281995639 ... 0.07985047037463823             1
#        x_0              x_fit       ...       y_0_unc       iter_detected
# ----------------- ----------------- ... ------------------- -------------
# 48.70939791198443 49.61842934591545 ... 0.10218383893114186             1
#        x_0              x_fit        ...       y_0_unc       iter_detected
# ----------------- ------------------ ... ------------------- -------------
# 46.94044639432528 47.428147383976665 ... 0.08020028959399773             1
#        x_0              x_fit        ...       y_0_unc       iter_detected
# ----------------- ------------------ ... ------------------- -------------
# 46.47810155948061 46.769154915394516 ... 0.09759445310888121             1
#        x_0               x_fit        ...       y_0_unc       iter_detected
# ------------------ ------------------ ... ------------------- -------------
#  46.47810155948061 46.769154915394516 ... 0.09759445310888121             1
#  47.59924343444381 47.827464151229506 ...  0.0964723324893014             1
#  45.80819589010773  45.85259838932409 ...  0.0909553779176946             1
# 45.697678056825765  45.68061452335745 ... 0.09684245887863646             1
#  46.47650109860289 47.097568283620475 ... 0.08157746035117652             1
#   46.7552697024983  47.24887161705092 ... 0.09330180618808992             1
#  46.53443742136066  47.10419305831734 ... 0.10302054658049421             1
#                ...                ... ...                 ...           ...
#  46.46269622986529  46.12066826174794 ... 0.08330694576008527             1
#  46.57884680437056  46.70161678340357 ... 0.10341848792003375             1
#  46.74461660540184 46.175220519334516 ... 0.09753969791964806             1
# 47.533106469027544 48.186763650726405 ... 0.09455070228316054             1
#  46.23331150267879  46.33621281995639 ... 0.07985047037463823             1
#  48.70939791198443  49.61842934591545 ... 0.10218383893114186             1
#  46.94044639432528 47.428147383976665 ... 0.08020028959399773             1
# Length = 22 rows

# %%
fig, axes = plt.subplots(5,4, figsize=(16,20))
for i, ax in enumerate(axes.flatten()):
    ax.imshow(resids[i], origin = 'lower')
    ax.set_xticks([])
    ax.set_yticks([])
plt.show()
